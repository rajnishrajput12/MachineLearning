# %% [markdown]
# ## K-mean clustering

# %%
from IPython.display import Image ## to display Image in notebook itself
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np
from sklearn.cluster import MiniBatchKMeans # to comrpess the color 
from scipy import misc
from PIL import Image ## to work with image

# %%
## https://jakevdp.github.io/PythonDataScienceHandbook/05.11-k-means.html

# %%
## we didvide the dataset into K cluster this K value calculated with ELBOW method using WSS(within sum square)
## we calcualte the distance of all the data poin from centrod (which is taken randomly nuber of centriod is equal to
## numbe rof k)
## then we again shift the centriod to new position and make clister and calcualte the distance of all the point from 
## this cluster this we keep on iterating it

# %%
Image(filename="K-MeanCluster.png", width=700,height=400)

# %%
data = pd.read_csv('Movie-Ratings.csv',header=0)
data.columns
data_movie = data[['Rotten Tomatoes Ratings %','Budget (million $)']]
data_movie
X=data['Rotten Tomatoes Ratings %'],
Y = data['Budget (million $)']

# %%
% matplotlib inline
plt.scatter(X,Y,)
plt.show()

# %% [markdown]
# ### poort example
# #### Kmeans how it works

# %%
data
# Out:
#     Pollution  Depth  Temperature
# 0         4.8     72          3.5
# 1         2.8     75          2.5
# 2         5.4     59          2.7
# 3         8.2     64          2.9
# 4         3.9     61          3.1
# 5         2.6     94          3.5
# 6         4.6     53          2.9
# 7         5.1     61          3.3
# 8         3.9     68          3.4
# 9        10.0     69          3.0
# 10        6.5     57          3.3
# 11        3.8     84          3.1
# 12        9.4     53          3.0
# 13        4.7     83          2.5
# 14        6.7    100          2.8
# 15        2.8     84          3.0
# 16        6.4     96          3.1
# 17        4.4     74          2.8
# 18        3.1     79          3.6
# 19        5.6     73          3.0
# 20        4.3     59          3.4
# 21        1.9     54          2.8
# 22        2.4     95          2.9
# 23        4.3     64          3.0
# 24        2.0     97          3.0
# 25        2.5     78          3.4
# ...

# %%
data = pd.read_excel('C:\\Users\\kumrajni\\Jupyter Learnign\\clustering\\clustering\\20170507_Batch26_CSE7405c_Clustering_Lab\\polutiondata.xlsx',header=0)
data.drop(['Id','Sediment','Depth'],axis=1,inplace=True)
plt.scatter(data.Pollution,data.Temperature)

# %%
cl = KMeans(n_clusters=2)
cl.fit(data)

y_Kmeans = cl.predict(data)
y_Kmeans_lable = cl.labels_

# %%
plt.scatter(data.Pollution,data.Temperature,c=y_Kmeans_lable)
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %% [markdown]
# #### K mean how it works

# %%
# %matplotlib inline
## K mean how it works 
## import the data 
from sklearn.datasets import make_blobs
X,y= make_blobs(n_samples=300,cluster_std=0.6,random_state=1)
data_sample = pd.DataFrame(X,y)
##print(data_sample)
plt.scatter(data_sample.loc[:,0],data_sample.loc[:,1])
##np.size(data_sample.loc[:,0])

# %%
## taking two random point (c1 and c2)
X
c1 = X[6]
c2=X[20]
## consider the one point as algoruithm is to find the distabce between from c1 and c2 from e1
## and whosever distance is less that point will be closer to that
e1 = X[0]
print(c1,c2,e1)
print(X[0])
# Out:
# [-10.0792989   -4.43171042] [ 10.0792989    4.43171042] [-10.61084407  -3.4766316 ]
# [-10.61084407  -3.4766316 ]

# %%
X.shape
# Out:
# (300, 2)

# %%
d1= np.add(np.round_(np.square(c1[0]-e1[0]),7), np.round_(np.square(c1[1]-e1[1]),7))
d2=np.add(np.round_(np.square(c2[0]-e1[0]),7), np.round_(np.square(c2[1]-e1[1]),7))
print(d1,d2)
## clearlt d1 is less than d2 so e1 belongs to c1 cluster
## now we will divide the point into two sets one will close to c1 and other to c2
## then we will calculate the mean of point in both sets then again will 
## calculate the distance of all point 
## this process we will do untill we reach convergence where we come to same centriod
# Out:
# 1.1947158 490.6238896

# %%
plt.scatter(X[:,0],X[:,1])

# %% [markdown]
# # color compression

# %%
## how image are stored and what is pixel
## https://www.youtube.com/watch?v=15aqFQQVBWU
## pixel are nothing but RGB with variours brightness 
## we can produce 16M vcolor with variying the brightess amonth RGB

# %%
## after this please look at cell after the god printed again with less number of colors
# Note: this requires the ``pillow`` package to be installed
from sklearn.datasets import load_sample_image
china = load_sample_image("china.jpg")
ax = plt.axes(xticks=[], yticks=[])
ax.imshow(china);

# %% [markdown]
# #### image to array
# ##### PIL pythin image library

# %%
# %matplotlib inline
pup_image = Image.open("puppy.jpg")
puppy =  np.array(pup_image)
puppy_axes = plt.axes(xticks=[], yticks=[])
puppy_axes.imshow(puppy)

# %%
puppy_data = puppy/255
puppy_data =  puppy.reshape(puppy.shape[0]*puppy.shape[1],3)
puppy_data.shape
# Out:
# (50512, 3)

# %%
kMea_puppY = MiniBatchKMeans(n_clusters=5000)
kMea_puppY.fit(puppy_data)
new_colors_puppy = kMea_puppY.cluster_centers_[kMea_puppY.predict(puppy_data)]
# Out:
# C:\Users\kumrajni\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:1418: RuntimeWarning: init_size=300 should be larger than k=5000. Setting it to 3*k
#   init_size=init_size)

# %%
puppy_recolored = new_colors_puppy.reshape(puppy.shape)

fig, ax = plt.subplots(1, 2, figsize=(16, 6),
                       subplot_kw=dict(xticks=[], yticks=[]))
fig.subplots_adjust(wspace=0.05)
ax[0].imshow(puppy)
ax[0].set_title('Original Image', size=16)
ax[1].imshow(puppy_recolored)
ax[1].set_title('16-color Image', size=16);

# %%
pypp = misc.imread('puppy.png')

# %%
n = np.arange(1,5)
n.shape
# Out:
# (4,)

# %% [markdown]
# resharping the data of china image// read the notbook for more detail i couldnt understand

# %%
data = china / 255.0 # use 0...1 scale
data = data.reshape(427 * 640, 3)
data
# Out:
# array([[ 0.68235294,  0.78823529,  0.90588235],
#        [ 0.68235294,  0.78823529,  0.90588235],
#        [ 0.68235294,  0.78823529,  0.90588235],
#        ...,
#        [ 0.16862745,  0.19215686,  0.15294118],
#        [ 0.05098039,  0.08235294,  0.02352941],
#        [ 0.05882353,  0.09411765,  0.02745098]])

# %%
visualizing the pixels

# %%
def plot_pixels(data, title, colors=None, N=10000):
    if colors is None:
        colors = data
    
    # choose a random subset
    rng = np.random.RandomState(0)
    i = rng.permutation(data.shape[0])[:N]
    colors = colors[i]
    R, G, B = data[i].T
    
    fig, ax = plt.subplots(1, 2, figsize=(16, 6))
    ax[0].scatter(R, G, color=colors, marker='.')
    ax[0].set(xlabel='Red', ylabel='Green', xlim=(0, 1), ylim=(0, 1))

    ax[1].scatter(R, B, color=colors, marker='.')
    ax[1].set(xlabel='Red', ylabel='Blue', xlim=(0, 1), ylim=(0, 1))

    fig.suptitle(title, size=20);

# %%
plot_pixels(data, title='Input color space: 16 million possible colors')

# %%
kMeansMini = MiniBatchKMeans(n_clusters=16)
kMeansMini.fit(data)
new_color = kMeansMini.cluster_centers_[kMeansMini.predict(data)]
plot_pixels(data, colors=new_color,
            title="Reduced color space: 16 colors")

# %%
china_recolored = new_color.reshape(china.shape)

fig, ax = plt.subplots(1, 2, figsize=(16, 6),
                       subplot_kw=dict(xticks=[], yticks=[]))
fig.subplots_adjust(wspace=0.05)
ax[0].imshow(china)
ax[0].set_title('Original Image', size=16)
ax[1].imshow(china_recolored)
ax[1].set_title('16-color Image', size=16);

# %% [markdown]
# Now let's reduce these 16 million colors to just 16 colors, using a k-means clustering across the pixel space. Because we are dealing with a very large dataset, we will use the mini batch k-means, which operates on subsets of the data to compute the result much more quickly than the standard k-means algorithm:

# %%
# reshape 2D array
from numpy import array
# list of data
data = [[11, 22],[33, 44],[55, 66]]
# array of data
data = array(data)
print(data.shape)
print(data)
# reshape
data = data.reshape((data.shape[0], data.shape[1], 1))
print(data.shape)
print(data)
# Out:
# (3, 2)
# [[11 22]
#  [33 44]
#  [55 66]]
# (3, 2, 1)
# [[[11]
#   [22]]
#
#  [[33]
#   [44]]
#
#  [[55]
#   [66]]]

# %%
# reshape 1D array
from numpy import array
from numpy import reshape
# define array
data = array([11, 22, 33, 44, 55])
print(data.shape)
# reshape
data = data.reshape((data.shape[0], 1))
print(data)
# Out:
# (5,)
# [[11]
#  [22]
#  [33]
#  [44]
#  [55]]
