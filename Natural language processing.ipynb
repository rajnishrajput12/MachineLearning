# %%
from nltk import word_tokenize
from nltk import sent_tokenize
##from nltk.book import
from IPython.display import Image
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import  state_union
from nltk import PunktSentenceTokenizer
from nltk import pos_tag as p
import  nltk

# %%
Image(filename="NLP1.PNG",width=600,height=500)
## lexical :- means breaking down the sentence with spaces 
## int x = 10;
## token will be int, x, =, 10, ;
##syntactic analusios:- is tagging those words into parts of speech like Article , verb, noun, pronoun
## symantic analysis :- it extracts the meaning from the dictionaryu or the sentence

# %%
Image(filename="NLP2.PNG",width=600,height=500)

# %%
text= "I am so fucking sick of this sentence and word tokenizing, please help me for god sake! and and and "

# %%
## we have created token which are words
word_token = word_tokenize(text)

# %%
print(len(word_token))
print(word_token)
# Out:
# 22
# ['I', 'am', 'so', 'fucking', 'sick', 'of', 'this', 'sentence', 'and', 'word', 'tokenizing', ',', 'please', 'help', 'me', 'for', 'god', 'sake', '!', 'and', 'and', 'and']

# %%
sente = "Hello Mr. Smith, how are you doing today? The weather is great, and Python is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."

# %%
## we have craeted toekn which are sentences
sent_token = sent_tokenize(sente)

# %%
print(sent_token)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and Python is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard."]

# %% [markdown]
# ## word tokenize takes string tyupe argument ##

# %%
word_sente = word_tokenize(sente)

# %%
print(len(word_sente))
# Out:
# 31

# %%
eng_stop_words =(stopwords.words('english'))
eng_stop_words[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
print(len(eng_stop_words))
# Out:
# 179

# %%
type(word_sente)
# Out:
# list

# %%
x = [word for word in word_sente if not word.lower() in eng_stop_words]

# %%
x
# Out:
# ['Hello',
#  'Mr.',
#  'Smith',
#  ',',
#  'today',
#  '?',
#  'weather',
#  'great',
#  ',',
#  'Python',
#  'awesome',
#  '.',
#  'sky',
#  'pinkish-blue',
#  '.',
#  "n't",
#  'eat',
#  'cardboard',
#  '.']

# %%
se2 = "This is a sample sentence, showing off the stop words filtration."
se2_wotd_token = word_tokenize(se2)

# %%
y = [word for word in se2_wotd_token if not word.lower() in eng_stop_words]
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-6c033167f2a1> in <module>()
# ----> 1 y = [word for word in se2_wotd_token if not word.lower() in eng_stop_words]
#       2 y
#
# NameError: name 'se2_wotd_token' is not defined

# %%
AI = """science and engineering of making intelligent machines, especially intelligent computer programs". The term "intelligence" is, of course, the subject of both scientific and philosophical debate. Within Artificial Intelligence many researchers use the term to mean giving computers behaviours which would be thought intelligent in human beings"""

# %%
AI_token = word_tokenize(AI)
print(len(AI_token))
# Out:
# 54

# %%
AI_token = [word for word in AI_token if not word.lower() in stopwords.words("english")]
print(len(AI_token))
# Out:
# 40

# %%
from nltk import FreqDist

# %%
for word in AI_token:
    FreqDist[word.lower()]+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-536f513357c3> in <module>()
#       1 for word in AI_token:
# ----> 2     FreqDist[word.lower()]+=1
#
# TypeError: 'type' object is not subscriptable

# %% [markdown]
# ## Stemming ###
# ### finding the meaning of a word or sentence by tracing its route to the parent word

# %%
ps = PorterStemmer()

# %%
ps.stem('doing')
# Out:
# 'do'

# %%
wordds = "hello hi how are you doing to do"
word2 = ['done', 'doing', 'do']

# %%
tok = word_tokenize(wordds)

# %%
for w in word2:
    print(ps.stem(w))
# Out:
# done
# do
# do

# %%
for w in tok:
    print(ps.stem(w))
# Out:
# hello
# hi
# how
# are
# you
# do
# to
# do

# %%
train_text = state_union.raw("2005-GWBush.txt")
test_text = state_union.raw("2006-GWBush.txt")

# %% [markdown]
# ## lemmatizing ##  ## parts of speech tagging ##

# %%
trai = PunktSentenceTokenizer(train_text)

# %%
test_tok = trai.tokenize(test_text)

# %%
test_tok
# Out:
# ["PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESIDENT: Thank you all.",
#  'Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream.',
#  'Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago, and we are grateful for the good life of Coretta Scott King.',
#  '(Applause.)',
#  'President George W. Bush reacts to applause during his State of the Union Address at the Capitol, Tuesday, Jan.',
#  '31, 2006.',
#  "White House photo by Eric DraperEvery time I'm invited to this rostrum, I'm humbled by the privilege, and mindful of the history we've seen together.",
# ...

# %%
test_tok[0]
# Out:
# "PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESIDENT: Thank you all."

# %%
print(word_tokenize(test_tok[0]))
p(word_tokenize(test_tok[0]))
# Out:
# ['PRESIDENT', 'GEORGE', 'W.', 'BUSH', "'S", 'ADDRESS', 'BEFORE', 'A', 'JOINT', 'SESSION', 'OF', 'THE', 'CONGRESS', 'ON', 'THE', 'STATE', 'OF', 'THE', 'UNION', 'January', '31', ',', '2006', 'THE', 'PRESIDENT', ':', 'Thank', 'you', 'all', '.']
# [('PRESIDENT', 'NNP'),
#  ('GEORGE', 'NNP'),
#  ('W.', 'NNP'),
#  ('BUSH', 'NNP'),
#  ("'S", 'POS'),
#  ('ADDRESS', 'NNP'),
#  ('BEFORE', 'IN'),
#  ('A', 'NNP'),
#  ('JOINT', 'NNP'),
#  ('SESSION', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('CONGRESS', 'NNP'),
#  ('ON', 'NNP'),
#  ('THE', 'NNP'),
#  ('STATE', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('UNION', 'NNP'),
#  ('January', 'NNP'),
#  ('31', 'CD'),
#  (',', ','),
#  ('2006', 'CD'),
#  ('THE', 'NNP'),
#  ('PRESIDENT', 'NNP'),
#  (':', ':'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('all', 'DT'),
#  ('.', '.')]

# %%
lemmatize = WordNetLemmatizer()

# %%
# %timeit
print(lemmatize.lemmatize('rocks'))
# Out:
# rock

# %% [markdown]
# ## tagging named entity ###

# %%
stri = ["hello my name is Rajnish and i am from bihar","bihar is beautifula state as in India"]

# %%
stri[0]
# Out:
# 'hello my name is Rajnish and i am from bihar'

# %%
token_stri = word_tokenize(stri[0])

# %%
tagged_stri = p(token_stri)

# %%
namedenti = nltk.ne_chunk(tagged_stri)

# %%
namedenti.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eaf576bed31d> in <module>()
# ----> 1 namedenti.draw()
#
# NameError: name 'namedenti' is not defined

# %%
from nltk.corpus import movie_reviews

# %%
(movie_reviews.words()[0x])
# Out:
# 'plot'

# %%
movie_reviews.words(fileid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-fcfd96bd2de6> in <module>()
# ----> 1 movie_reviews.words(fileid)
#
# NameError: name 'fileid' is not defined

# %%
w = word_tokenize(stri[0])
wr = nltk.FreqDist(w)

# %%
wr['is']
# Out:
# 1
